# %%
import numpy as np

def extract_data(filename) :
    import numpy as np
    import re
    f = open(filename,'r').read();

    p = re.compile(u'Iteration ([0-9]+), loss = ([0-9]+\.[0-9]+)\n.+Train net output #0: accuracy = ([0-9]*\.*[0-9]+)\n')

    data = {}
    
    it_ = [];
    loss_ = [];
    acc_ = [];
    for it, loss, acc in re.findall(p,f):
        it_.append(int(it))
        loss_.append(float(loss));
        acc_.append(float(acc))
    data['loss'] = {'iteration':np.array(it_),'loss':np.array(loss_)}
    data['train_accuracy']={'iteration':np.array(it_),'accuracy':np.array(acc_)}
    
    it_ = [];
    acc_ = [];
    p = re.compile(u'Iteration ([0-9]+), Testing net \(#0\)\n.+Test net output #0: accuracy = ([0-9]*\.*[0-9]+)\(.+\)\n')
    for it, acc in  re.findall(p,f):
        it_.append(int(it))
        acc_.append(float(acc))
    data['test_accuracy']={'iteration':np.array(it_),'accuracy':np.array(acc_)}

    return data


data = extract_data('./logs/2015-05-29_12_59.log')

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm

fig, ax1 = plt.subplots()
ax1.plot(data['loss']['iteration'],data['loss']['loss'])
ax2 = ax1.twinx()
ax2.plot(data['test_accuracy']['iteration'],data['test_accuracy']['accuracy'])
ax2.plot(data['train_accuracy']['iteration'],data['train_accuracy']['accuracy'])
plt.show()

fig.clf()
print data['test_accuracy']
# Out:
# {'iteration': array([   0, 1000, 2000, 3000, 4000, 5000]), 'accuracy': array([ 0.5894 ,  0.56772,  0.58362,  0.5847 ,  0.5847 ,  0.58468])}

# %%
from IPython.display import display, clear_output
import sys, time
while(True):
    data = extract_data('../super_category_finetuning/2015-06-02_06_13.log')
    fig, ax1 = plt.subplots()
    ax1.plot(data['loss']['iteration'],data['loss']['loss'],label='loss')
    ax1.legend(loc=0)
    ax2 = ax1.twinx()
    ax2.plot(data['test_accuracy']['iteration'],data['test_accuracy']['accuracy'],label='test_accuracy',linestyle='--')
    ax2.plot(data['train_accuracy']['iteration'],data['train_accuracy']['accuracy'],label='train_accuracy',linestyle='--')
    ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    fig.clf()

    data = extract_data('../super_category/2015-05-31_16_08.log')
    fig, ax1 = plt.subplots()
    ax1.plot(data['loss']['iteration'],data['loss']['loss'],label='loss')
    ax1.legend(loc=0)
    ax2 = ax1.twinx()
    ax2.plot(data['test_accuracy']['iteration'],data['test_accuracy']['accuracy'],label='test_accuracy',linestyle='--')
    ax2.plot(data['train_accuracy']['iteration'],data['train_accuracy']['accuracy'],label='train_accuracy',linestyle='--')
    ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()
    fig.clf()
    clear_output(wait=True)
    time.sleep(60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-cc14ef4a64b3> in <module>()
#      24     fig.clf()
#      25     clear_output(wait=True)
# ---> 26     time.sleep(60)
#
# KeyboardInterrupt:
